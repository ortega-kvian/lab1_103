# %% [markdown]
# <a href="https://colab.research.google.com/github/ortega-kvian/lab1_103/blob/main/diagrama_de_caja_Ortega_Karla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Diagrama de Caja

# %%
import pandas as pd
import matplotlib.pyplot as plt

path= "/content/drive/MyDrive/Conjunto de datos/pepeatenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv"

# Craar un dataframe
df =pd.read_csv(path)

# filtrado
df_filtrado = df.query("usuaria_edad <= 160")

print(df_filtrado["usuaria_edad"])

# Crear el diagrama de caja
plt.boxplot(df_filtrado["usuaria_edad"])

# Mostrar el diagrama de caja
plt.show()
# Out:
# <ipython-input-1-76419db91e7b>:7: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df =pd.read_csv(path)
# 0         33.0
# 1         26.0
# 2         25.0
# 3         55.0
# 4         33.0
#           ...
# 121990    50.0
# 121991    31.0
# 121992    20.0
# 121993    26.0
# 121994    31.0
# Name: usuaria_edad, Length: 119978, dtype: float64

# %% [markdown]
# Diagrama de linea

# %%
import pandas as pd
import matplotlib.pyplot as plt


# Obtener url de archivo csv
path ="/content/drive/MyDrive/Conjunto de datos/pepeatenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv"

# Leer el CSV
df = pd.read_csv(path)

# Obtener el conteo de cada categoría
conteo = df["anio_mes"].value_counts()


# Crear un gráfico de línea con dos líneas
plt.plot (df["anio"],df ["mes"], color="blue")

plt.show()
# Out:
# <ipython-input-17-2c8f56044b2d>:9: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Obtener url de archivo csv
path= "/content/drive/MyDrive/Conjunto de datos/pepeatenciones_abogadas_de_las_mujeres - atenciones_abogadas_de_las_mujeres.csv"
# Leer el CSV
df = pd.read_csv(path)
# Obtener el conteo de cada categoria
conteo= df["anio_mes"].value_counts()

#Crear un grafico de linea con dos lineas
plt.plot(conteo, conteo.index, color="blue")

plt.show()
# Out:
# <ipython-input-14-65909ee0b9c7>:7: DtypeWarning: Columns (14,19,20,21) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(path)
